# %%
# Tensorflow imports
# from tensorflow.test import is_gpu_available
from tensorflow.keras.models import Sequential, load_model, model_from_json, Model
from tensorflow.keras.layers import Dense, Dropout, Input, BatchNormalization, LSTM, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard, ModelCheckpoint
from tensorflow.keras import backend as K
from tensorflow.keras import optimizers, regularizers

# Sklearn imports
from sklearn.preprocessing import Normalizer, MinMaxScaler, StandardScaler, RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Mongo
from pymongo import MongoClient

# Pandas and numpy
import pandas as pd
import numpy as np
pd.options.mode.chained_assignment = None

# Plotting
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(18, 4)})

# Hyperopt
from hyperopt import hp, fmin, tpe, STATUS_OK, STATUS_FAIL, Trials, space_eval, rand

# Warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# Other
from scipy.ndimage.filters import gaussian_filter1d
from IPython.display import Image
from datetime import datetime, timedelta
from math import sqrt

import logging, os
logging.disable(logging.WARNING)
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

# %%
sns.set(rc={'figure.figsize':(18, 4)})

# %% [markdown]
# ### Connect to mongo database

# %%
# Mongo client
client = MongoClient('mongodb://165.22.199.122:27017')
db = client.processed
data = db.internal

# %%
# Load the data
df= (pd.DataFrame(list(data.find()))
    .drop(['_id', 'window'], 1)
    .set_index('timestamp')
    .sort_index()
    .dropna())

df['price_diff'] = df['price'].diff(1)
df = df.dropna()
df = df[df['price_diff'].abs() < 40]
df = df[df['n_tweets'] >= 190]
df = df.iloc[3:-3]

print(df.shape)
df.head()
# Out:
# (5286, 4)
#                      n_tweets     price  sentiment  price_diff
# timestamp
# 2019-11-03 14:58:00       316  9192.100   0.173610       2.921
# 2019-11-03 15:00:00       313  9195.474   0.163184       3.374
# 2019-11-03 15:02:00       385  9193.544   0.151912      -1.930
# 2019-11-03 15:04:00       429  9190.258   0.135992      -3.286
# 2019-11-03 15:06:00       473  9186.290   0.145232      -3.968

# %% [markdown]
# ### Function to create timeline plot

# %%
def plot_timeline(first_feature, second_feature):
    sns.set_style("dark")
    
    fig, ax1 = plt.subplots()

    ax1.plot(df['2019-01-02 08:00:00':][first_feature], label=first_feature)
    ax1.legend(loc='upper left')
    ax2 = ax1.twinx()
    ax2.plot(df['2019-01-02 08:00:00':][second_feature], color='orange', label=second_feature)
    ax2.legend(loc='upper right')

# %%
plot_timeline('sentiment', 'price')

# %%
plot_timeline('n_tweets', 'price_diff')

# %% [markdown]
# ### Prepare training data

# %%
df['price'].head()
# Out:
# timestamp
# 2019-11-03 14:58:00    9192.100
# 2019-11-03 15:00:00    9195.474
# 2019-11-03 15:02:00    9193.544
# 2019-11-03 15:04:00    9190.258
# 2019-11-03 15:06:00    9186.290
# Name: price, dtype: float64

# %%
split_sequence(df['price'], 3)

# %%
train_size = int(.75 * len(df))

price_diff = df['price_diff'].values
price_diff_train, price_diff_test = price_diff[:train_size], price_diff[train_size:]

sentiment = df['sentiment'].values
sentiment_train, sentiment_test = sentiment[:train_size], sentiment[train_size:]

n_tweets = df['n_tweets'].values
n_tweets_train, n_tweets_test = n_tweets[:train_size], n_tweets[train_size:]

data = np.stack([price_diff_train, sentiment_train, n_tweets_train], axis=1)

data_split = split_sequence(data, 12)

# %%
np.set_printoptions(suppress=True)

# %%
data_split[0].flatten('F')
# Out:
# array([ -3.0225    ,  -0.72916667,  -1.86333333,   3.374     ,
#          2.288     ,   2.502     ,   2.921     ,   3.374     ,
#         -1.93      ,  -3.286     ,  -3.968     ,   0.393     ,
#          0.24112466,   0.25534524,   0.25383859,   0.21677549,
#          0.21157235,   0.19037853,   0.17361044,   0.16318371,
#          0.15191169,   0.13599184,   0.1452315 ,   0.1468129 ,
#         73.        , 126.        , 184.        , 257.        ,
#        311.        , 312.        , 316.        , 313.        ,
#        385.        , 429.        , 473.        , 504.        ])

# %%
data_split.reshape(-1, 12*3, order='F')[0]
# Out:
# array([ -1.93      ,  -3.286     ,  -3.968     ,   0.393     ,
#          4.168     ,   4.188     ,   5.621     ,   6.602     ,
#          0.556     ,  -2.253     ,  -2.285     ,  -2.369     ,
#          0.15191169,   0.13599184,   0.1452315 ,   0.1468129 ,
#          0.13215627,   0.14367148,   0.15276477,   0.13937879,
#          0.1348307 ,   0.14266518,   0.13861673,   0.15006024,
#        385.        , 429.        , 473.        , 504.        ,
#        558.        , 512.        , 474.        , 462.        ,
#        456.        , 471.        , 490.        , 503.        ])

# %%
def split_sequence(sequence, n_steps):
    X = []
    for i in range(len(sequence)):
        end_ix = i + n_steps
        if end_ix > len(sequence)-1:
            break
        seq_x = sequence[i:end_ix]
        X.append(seq_x)
        
    return np.array(X)

def generate_train_test(n_steps=12, train_size=.75, flatten=True):
    train_size = int(train_size * len(df))
    
    prices = df['price'].values
    prices_train, prices_test = prices[:train_size], prices[train_size:]
    
    price_diff = df['price_diff'].values
    price_diff_train, price_diff_test = price_diff[:train_size], price_diff[train_size:]
    
    sentiment = df['sentiment'].values
    sentiment_train, sentiment_test = sentiment[:train_size], sentiment[train_size:]
    
    n_tweets = df['n_tweets'].values
    n_tweets_train, n_tweets_test = n_tweets[:train_size], n_tweets[train_size:]
    
    train = np.stack([prices_train, sentiment_train, n_tweets_train], axis=1)
    test = np.stack([prices_test, sentiment_test, n_tweets_test], axis=1)
    
    # Scale the data
    scaler = StandardScaler()
    train_scaled = scaler.fit_transform(train)
    test_scaled = scaler.transform(test)
    scaler_mean = scaler.mean_
    scaler_var = scaler.var_
    
    # Create the sequence
    X_train = split_sequence(train, n_steps)
    X_test = split_sequence(test, n_steps)
    
    y_prices = df['price']

    y_train = y_prices.iloc[n_steps:len(X_train)+n_steps].values
    y_test = y_prices.iloc[-len(X_test):].values
    
    # Flatten the timeseries
    if flatten:
        X_train = X_train.reshape(-1, X_train.shape[1]*X_train.shape[2], order='F')
        X_test = X_test.reshape(-1, X_test.shape[1]*X_test.shape[2], order='F')
        
    return X_train, X_test, y_train, y_test, (scaler_mean, scaler_var)

# %%
X_train, X_test, y_train, y_test, scaler_values = generate_train_test(n_steps=3, flatten=True)
X_train.shape
# Out:
# (3961, 9)

# %%
X_train[0]
# Out:
# array([9.19210000e+03, 9.19547400e+03, 9.19354400e+03, 1.73610443e-01,
#        1.63183706e-01, 1.51911688e-01, 3.16000000e+02, 3.13000000e+02,
#        3.85000000e+02])

# %%
y_train[0]
# Out:
# 9190.258

# %%
scaler_values
# Out:
# (array([9.14809815e+03, 1.71638227e-01, 4.06556004e+02]),
#  array([5.29357681e+04, 1.64774550e-03, 9.19667068e+03]))

# %% [markdown]
# ### Build the keras model

# %%
# model.add(BatchNormalization())
# model.add(Dropout(.65))
# model.add(Dense(41, activation='relu'))
# model.add(LSTM(32, activation='relu'))
# model.add(LSTM(64, activation='relu', input_shape=(n_steps, n_features), return_sequences=True))

# %%
def root_mean_squared_error(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true))) 

def build_lstm_model():
    model = Sequential()
    
    model.add(LSTM(32, activation='relu', input_shape=(3, 4)))
    model.add(Dense(16, activation='relu'))
    
    model.add(Dense(1))
    model.compile(optimizer='rmsprop', loss=root_mean_squared_error)
    
    return model

def build_model():
    model = Sequential()
    model.add(Dense(16, activation='relu', input_shape=(X_train.shape[1],), 
#                     kernel_regularizer=regularizers.l2(0.01)
                   ))
    
    model.add(Dense(8, activation='relu', 
#                     kernel_regularizer=regularizers.l2(0.01)
                   ))
        
    model.add(Dense(1))
    model.save('model')
    model.compile(optimizer='adam', loss=root_mean_squared_error)
    
    return model

# %%
# Create the model
model = build_model()
model.summary()

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=32)

# Checkpoints
checkpointer = ModelCheckpoint(filepath='models/keras_weights.hdf5',
                                   verbose=1,
                                   save_best_only=True)

# Fit the model
model.fit(
    X_train, 
    y_train, 
    validation_split=0.33,
    epochs=256, 
    batch_size=64,
    callbacks=[checkpointer, early_stopping]);
# Out:
# Model: "sequential_51"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_141 (Dense)            (None, 16)                160
# _________________________________________________________________
# dense_142 (Dense)            (None, 8)                 136
# _________________________________________________________________
# dense_143 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 305
# Trainable params: 305
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2653 samples, validate on 1308 samples
# Epoch 1/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 6439.6191
# Epoch 00001: val_loss improved from inf to 3797.46366, saving model to models/keras_weights.hdf5
# 2653/2653 [==============================] - 1s 227us/sample - loss: 6059.4861 - val_loss: 3797.4637
# Epoch 2/256
# 1920/2653 [====================>.........] - ETA: 0s - loss: 2823.7449
# Epoch 00002: val_loss improved from 3797.46366 to 156.04078, saving model to models/keras_weights.hdf5
# 2653/2653 [==============================] - 0s 50us/sample - loss: 2289.5504 - val_loss: 156.0408
# Epoch 3/256
# 1984/2653 [=====================>........] - ETA: 0s - loss: 173.8349
# Epoch 00003: val_loss improved from 156.04078 to 83.39578, saving model to models/keras_weights.hdf5
# 2653/2653 [==============================] - 0s 52us/sample - loss: 153.6298 - val_loss: 83.3958
# Epoch 4/256
# 1664/2653 [=================>............] - ETA: 0s - loss: 82.1040
# Epoch 00004: val_loss improved from 83.39578 to 73.38692, saving model to models/keras_weights.hdf5
# 2653/2653 [==============================] - 0s 62us/sample - loss: 79.2676 - val_loss: 73.3869
# Epoch 5/256
# 1536/2653 [================>.............] - ETA: 0s - loss: 71.1362
# Epoch 00005: val_loss improved from 73.38692 to 53.47604, saving model to models/keras_weights.hdf5
# 2653/2653 [==============================] - 0s 55us/sample - loss: 65.4832 - val_loss: 53.4760
# Epoch 6/256
# 1984/2653 [=====================>........] - ETA: 0s - loss: 52.4207
# Epoch 00006: val_loss improved from 53.47604 to 52.05746, saving model to models/keras_weights.hdf5
# 2653/2653 [==============================] - 0s 53us/sample - loss: 51.3308 - val_loss: 52.0575
# Epoch 7/256
# 1856/2653 [===================>..........] - ETA: 0s - loss: 43.2439
# Epoch 00007: val_loss improved from 52.05746 to 36.25536, saving model to models/keras_weights.hdf5
# 2653/2653 [==============================] - 0s 55us/sample - loss: 41.3246 - val_loss: 36.2554
# Epoch 8/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 33.2283
# Epoch 00008: val_loss improved from 36.25536 to 28.03210, saving model to models/keras_weights.hdf5
# 2653/2653 [==============================] - 0s 48us/sample - loss: 32.5107 - val_loss: 28.0321
# Epoch 9/256
# 2048/2653 [======================>.......] - ETA: 0s - loss: 24.4861
# Epoch 00009: val_loss improved from 28.03210 to 17.68356, saving model to models/keras_weights.hdf5
# 2653/2653 [==============================] - 0s 48us/sample - loss: 23.3118 - val_loss: 17.6836
# Epoch 10/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 17.3499
# Epoch 00010: val_loss improved from 17.68356 to 11.64482, saving model to models/keras_weights.hdf5
# 2653/2653 [==============================] - 0s 47us/sample - loss: 16.6193 - val_loss: 11.6448
# Epoch 11/256
# 1920/2653 [====================>.........] - ETA: 0s - loss: 10.9738
# Epoch 00011: val_loss improved from 11.64482 to 9.02668, saving model to models/keras_weights.hdf5
# 2653/2653 [==============================] - 0s 54us/sample - loss: 10.9921 - val_loss: 9.0267
# Epoch 12/256
# 1728/2653 [==================>...........] - ETA: 0s - loss: 12.6156
# Epoch 00012: val_loss did not improve from 9.02668
# 2653/2653 [==============================] - 0s 47us/sample - loss: 11.2689 - val_loss: 9.0369
# Epoch 13/256
# 1984/2653 [=====================>........] - ETA: 0s - loss: 11.0145
# Epoch 00013: val_loss improved from 9.02668 to 8.90757, saving model to models/keras_weights.hdf5
# 2653/2653 [==============================] - 0s 58us/sample - loss: 11.8310 - val_loss: 8.9076
# Epoch 14/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 10.3546
# Epoch 00014: val_loss did not improve from 8.90757
# 2653/2653 [==============================] - 0s 39us/sample - loss: 10.4324 - val_loss: 13.5230
# Epoch 15/256
# 1728/2653 [==================>...........] - ETA: 0s - loss: 13.1326
# Epoch 00015: val_loss did not improve from 8.90757
# 2653/2653 [==============================] - 0s 46us/sample - loss: 12.7298 - val_loss: 13.0394
# Epoch 16/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 11.3683
# Epoch 00016: val_loss did not improve from 8.90757
# 2653/2653 [==============================] - 0s 39us/sample - loss: 11.9329 - val_loss: 10.9057
# Epoch 17/256
# 1728/2653 [==================>...........] - ETA: 0s - loss: 9.6972
# Epoch 00017: val_loss improved from 8.90757 to 8.10801, saving model to models/keras_weights.hdf5
# 2653/2653 [==============================] - 0s 54us/sample - loss: 9.4289 - val_loss: 8.1080
# Epoch 18/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 8.5580
# Epoch 00018: val_loss did not improve from 8.10801
# 2653/2653 [==============================] - 0s 43us/sample - loss: 9.0451 - val_loss: 16.7609
# Epoch 19/256
# 1664/2653 [=================>............] - ETA: 0s - loss: 11.8538
# Epoch 00019: val_loss did not improve from 8.10801
# 2653/2653 [==============================] - 0s 42us/sample - loss: 10.7747 - val_loss: 8.7803
# Epoch 20/256
# 2304/2653 [=========================>....] - ETA: 0s - loss: 10.7838
# Epoch 00020: val_loss did not improve from 8.10801
# 2653/2653 [==============================] - 0s 37us/sample - loss: 11.5801 - val_loss: 19.0078
# Epoch 21/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 11.9405
# Epoch 00021: val_loss did not improve from 8.10801
# 2653/2653 [==============================] - 0s 37us/sample - loss: 11.4189 - val_loss: 14.3494
# Epoch 22/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 11.6395
# Epoch 00022: val_loss did not improve from 8.10801
# 2653/2653 [==============================] - 0s 38us/sample - loss: 10.7518 - val_loss: 8.7117
# Epoch 23/256
# 2304/2653 [=========================>....] - ETA: 0s - loss: 8.8332
# Epoch 00023: val_loss improved from 8.10801 to 7.89951, saving model to models/keras_weights.hdf5
# 2653/2653 [==============================] - 0s 50us/sample - loss: 8.7357 - val_loss: 7.8995
# Epoch 24/256
# 1664/2653 [=================>............] - ETA: 0s - loss: 11.3043
# Epoch 00024: val_loss did not improve from 7.89951
# 2653/2653 [==============================] - 0s 50us/sample - loss: 10.7431 - val_loss: 14.1271
# Epoch 25/256
# 1856/2653 [===================>..........] - ETA: 0s - loss: 10.3954
# Epoch 00025: val_loss did not improve from 7.89951
# 2653/2653 [==============================] - 0s 41us/sample - loss: 9.9162 - val_loss: 12.3161
# Epoch 26/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 11.9309
# Epoch 00026: val_loss did not improve from 7.89951
# 2653/2653 [==============================] - 0s 37us/sample - loss: 11.7483 - val_loss: 11.6004
# Epoch 27/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 10.1556
# Epoch 00027: val_loss did not improve from 7.89951
# 2653/2653 [==============================] - 0s 37us/sample - loss: 10.2253 - val_loss: 10.8186
# Epoch 28/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 9.0920
# Epoch 00028: val_loss improved from 7.89951 to 7.84038, saving model to models/keras_weights.hdf5
# 2653/2653 [==============================] - 0s 51us/sample - loss: 9.1942 - val_loss: 7.8404
# Epoch 29/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 10.6702
# Epoch 00029: val_loss improved from 7.84038 to 7.50997, saving model to models/keras_weights.hdf5
# 2653/2653 [==============================] - 0s 48us/sample - loss: 10.1795 - val_loss: 7.5100
# Epoch 30/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 9.0674
# Epoch 00030: val_loss did not improve from 7.50997
# 2653/2653 [==============================] - 0s 38us/sample - loss: 9.3520 - val_loss: 12.5219
# Epoch 31/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 10.7345
# Epoch 00031: val_loss did not improve from 7.50997
# 2653/2653 [==============================] - 0s 37us/sample - loss: 10.3186 - val_loss: 7.6203
# Epoch 32/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 9.4241
# Epoch 00032: val_loss did not improve from 7.50997
# 2653/2653 [==============================] - 0s 40us/sample - loss: 9.4198 - val_loss: 16.5813
# Epoch 33/256
# 2304/2653 [=========================>....] - ETA: 0s - loss: 11.8409
# Epoch 00033: val_loss did not improve from 7.50997
# 2653/2653 [==============================] - 0s 37us/sample - loss: 11.4265 - val_loss: 10.9094
# Epoch 34/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 10.4332
# Epoch 00034: val_loss did not improve from 7.50997
# 2653/2653 [==============================] - 0s 39us/sample - loss: 10.1928 - val_loss: 15.0796
# Epoch 35/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 9.3565
# Epoch 00035: val_loss improved from 7.50997 to 7.25046, saving model to models/keras_weights.hdf5
# 2653/2653 [==============================] - 0s 49us/sample - loss: 9.6080 - val_loss: 7.2505
# Epoch 36/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 9.4557
# Epoch 00036: val_loss did not improve from 7.25046
# 2653/2653 [==============================] - 0s 37us/sample - loss: 9.5237 - val_loss: 12.7367
# Epoch 37/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 10.3887
# Epoch 00037: val_loss did not improve from 7.25046
# 2653/2653 [==============================] - 0s 37us/sample - loss: 10.3340 - val_loss: 7.9884
# Epoch 38/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 7.6797
# Epoch 00038: val_loss improved from 7.25046 to 7.12079, saving model to models/keras_weights.hdf5
# 2653/2653 [==============================] - 0s 52us/sample - loss: 7.8918 - val_loss: 7.1208
# Epoch 39/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 9.0649
# Epoch 00039: val_loss did not improve from 7.12079
# 2653/2653 [==============================] - 0s 38us/sample - loss: 9.3237 - val_loss: 7.9039
# Epoch 40/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 8.5165
# Epoch 00040: val_loss did not improve from 7.12079
# 2653/2653 [==============================] - 0s 38us/sample - loss: 9.1611 - val_loss: 8.1992
# Epoch 41/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 13.2875
# Epoch 00041: val_loss did not improve from 7.12079
# 2653/2653 [==============================] - 0s 38us/sample - loss: 14.1224 - val_loss: 20.3523
# Epoch 42/256
# 2304/2653 [=========================>....] - ETA: 0s - loss: 16.4016
# Epoch 00042: val_loss did not improve from 7.12079
# 2653/2653 [==============================] - 0s 36us/sample - loss: 15.4121 - val_loss: 12.8862
# Epoch 43/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 8.9267
# Epoch 00043: val_loss did not improve from 7.12079
# 2653/2653 [==============================] - 0s 38us/sample - loss: 8.9228 - val_loss: 8.0940
# Epoch 44/256
# 1984/2653 [=====================>........] - ETA: 0s - loss: 10.2472
# Epoch 00044: val_loss did not improve from 7.12079
# 2653/2653 [==============================] - 0s 39us/sample - loss: 10.4279 - val_loss: 10.9537
# Epoch 45/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 12.2998
# Epoch 00045: val_loss did not improve from 7.12079
# 2653/2653 [==============================] - 0s 37us/sample - loss: 12.2168 - val_loss: 12.6701
# Epoch 46/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 10.0992
# Epoch 00046: val_loss did not improve from 7.12079
# 2653/2653 [==============================] - 0s 38us/sample - loss: 9.8899 - val_loss: 11.2019
# Epoch 47/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 9.5504
# Epoch 00047: val_loss did not improve from 7.12079
# 2653/2653 [==============================] - 0s 38us/sample - loss: 9.8352 - val_loss: 8.6577
# Epoch 48/256
# 2304/2653 [=========================>....] - ETA: 0s - loss: 17.6970
# Epoch 00048: val_loss did not improve from 7.12079
# 2653/2653 [==============================] - 0s 37us/sample - loss: 17.1895 - val_loss: 10.8853
# Epoch 49/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 9.2597
# Epoch 00049: val_loss did not improve from 7.12079
# 2653/2653 [==============================] - 0s 38us/sample - loss: 9.4675 - val_loss: 10.7295
# Epoch 50/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 8.5859
# Epoch 00050: val_loss did not improve from 7.12079
# 2653/2653 [==============================] - 0s 37us/sample - loss: 8.2245 - val_loss: 7.2513
# Epoch 51/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 8.5400
# Epoch 00051: val_loss did not improve from 7.12079
# 2653/2653 [==============================] - 0s 38us/sample - loss: 9.1075 - val_loss: 8.2063
# Epoch 52/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 9.9137
# Epoch 00052: val_loss did not improve from 7.12079
# 2653/2653 [==============================] - 0s 41us/sample - loss: 9.7837 - val_loss: 7.3342
# Epoch 53/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 6.7431
# Epoch 00053: val_loss did not improve from 7.12079
# 2653/2653 [==============================] - 0s 39us/sample - loss: 7.2154 - val_loss: 7.8618
# Epoch 54/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 10.8408
# Epoch 00054: val_loss did not improve from 7.12079
# 2653/2653 [==============================] - 0s 37us/sample - loss: 10.8388 - val_loss: 10.2941
# Epoch 55/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 7.6810
# Epoch 00055: val_loss improved from 7.12079 to 6.74198, saving model to models/keras_weights.hdf5
# 2653/2653 [==============================] - 0s 48us/sample - loss: 7.8492 - val_loss: 6.7420
# Epoch 56/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 10.8879
# Epoch 00056: val_loss improved from 6.74198 to 6.71235, saving model to models/keras_weights.hdf5
# 2653/2653 [==============================] - 0s 52us/sample - loss: 10.7447 - val_loss: 6.7123
# Epoch 57/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 8.6676
# Epoch 00057: val_loss did not improve from 6.71235
# 2653/2653 [==============================] - 0s 41us/sample - loss: 9.8549 - val_loss: 7.1266
# Epoch 58/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 11.4435
# Epoch 00058: val_loss did not improve from 6.71235
# 2653/2653 [==============================] - 0s 38us/sample - loss: 10.9963 - val_loss: 7.8524
# Epoch 59/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 7.6355
# Epoch 00059: val_loss improved from 6.71235 to 6.64504, saving model to models/keras_weights.hdf5
# 2653/2653 [==============================] - 0s 48us/sample - loss: 7.4144 - val_loss: 6.6450
# Epoch 60/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 9.8271
# Epoch 00060: val_loss did not improve from 6.64504
# 2653/2653 [==============================] - 0s 37us/sample - loss: 9.8387 - val_loss: 10.6957
# Epoch 61/256
# 2304/2653 [=========================>....] - ETA: 0s - loss: 8.8613
# Epoch 00061: val_loss improved from 6.64504 to 6.59784, saving model to models/keras_weights.hdf5
# 2653/2653 [==============================] - 0s 47us/sample - loss: 8.8955 - val_loss: 6.5978
# Epoch 62/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 7.0331
# Epoch 00062: val_loss did not improve from 6.59784
# 2653/2653 [==============================] - 0s 37us/sample - loss: 7.5344 - val_loss: 7.2036
# Epoch 63/256
# 2304/2653 [=========================>....] - ETA: 0s - loss: 9.2165
# Epoch 00063: val_loss did not improve from 6.59784
# 2653/2653 [==============================] - 0s 37us/sample - loss: 9.4031 - val_loss: 8.6601
# Epoch 64/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 9.2968
# Epoch 00064: val_loss did not improve from 6.59784
# 2653/2653 [==============================] - 0s 38us/sample - loss: 9.1624 - val_loss: 13.2211
# Epoch 65/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 13.6331
# Epoch 00065: val_loss did not improve from 6.59784
# 2653/2653 [==============================] - 0s 38us/sample - loss: 12.8474 - val_loss: 10.6898
# Epoch 66/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 9.0427
# Epoch 00066: val_loss did not improve from 6.59784
# 2653/2653 [==============================] - 0s 38us/sample - loss: 9.5008 - val_loss: 20.0865
# Epoch 67/256
# 1984/2653 [=====================>........] - ETA: 0s - loss: 16.6598
# Epoch 00067: val_loss did not improve from 6.59784
# 2653/2653 [==============================] - 0s 40us/sample - loss: 15.3966 - val_loss: 12.6266
# Epoch 68/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 9.6723
# Epoch 00068: val_loss did not improve from 6.59784
# 2653/2653 [==============================] - 0s 38us/sample - loss: 9.5934 - val_loss: 6.7208
# Epoch 69/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 15.6121
# Epoch 00069: val_loss improved from 6.59784 to 6.52467, saving model to models/keras_weights.hdf5
# 2653/2653 [==============================] - 0s 47us/sample - loss: 14.6928 - val_loss: 6.5247
# Epoch 70/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 6.8716
# Epoch 00070: val_loss did not improve from 6.52467
# 2653/2653 [==============================] - 0s 40us/sample - loss: 7.0759 - val_loss: 7.4170
# Epoch 71/256
# 1984/2653 [=====================>........] - ETA: 0s - loss: 9.1195
# Epoch 00071: val_loss did not improve from 6.52467
# 2653/2653 [==============================] - 0s 39us/sample - loss: 8.5495 - val_loss: 7.3047
# Epoch 72/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 8.1747
# Epoch 00072: val_loss did not improve from 6.52467
# 2653/2653 [==============================] - 0s 37us/sample - loss: 8.2615 - val_loss: 8.8144
# Epoch 73/256
# 2304/2653 [=========================>....] - ETA: 0s - loss: 9.8824
# Epoch 00073: val_loss did not improve from 6.52467
# 2653/2653 [==============================] - 0s 37us/sample - loss: 9.5209 - val_loss: 6.6992
# Epoch 74/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 7.0560
# Epoch 00074: val_loss did not improve from 6.52467
# 2653/2653 [==============================] - 0s 39us/sample - loss: 7.5866 - val_loss: 8.5643
# Epoch 75/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 9.6174
# Epoch 00075: val_loss did not improve from 6.52467
# 2653/2653 [==============================] - 0s 38us/sample - loss: 9.2229 - val_loss: 8.8797
# Epoch 76/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 10.3842
# Epoch 00076: val_loss did not improve from 6.52467
# 2653/2653 [==============================] - 0s 37us/sample - loss: 10.6542 - val_loss: 11.0209
# Epoch 77/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 8.3501
# Epoch 00077: val_loss did not improve from 6.52467
# 2653/2653 [==============================] - 0s 37us/sample - loss: 8.5176 - val_loss: 9.1443
# Epoch 78/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 10.0704
# Epoch 00078: val_loss did not improve from 6.52467
# 2653/2653 [==============================] - 0s 38us/sample - loss: 9.9624 - val_loss: 7.1719
# Epoch 79/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 8.8010
# Epoch 00079: val_loss did not improve from 6.52467
# 2653/2653 [==============================] - 0s 38us/sample - loss: 9.1094 - val_loss: 9.3574
# Epoch 80/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 10.3013
# Epoch 00080: val_loss did not improve from 6.52467
# 2653/2653 [==============================] - 0s 37us/sample - loss: 9.7317 - val_loss: 11.0792
# Epoch 81/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 9.7340
# Epoch 00081: val_loss did not improve from 6.52467
# 2653/2653 [==============================] - 0s 39us/sample - loss: 10.2886 - val_loss: 15.2433
# Epoch 82/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 8.9163
# Epoch 00082: val_loss did not improve from 6.52467
# 2653/2653 [==============================] - 0s 39us/sample - loss: 8.8489 - val_loss: 6.9575
# Epoch 83/256
# 2368/2653 [=========================>....] - ETA: 0s - loss: 9.2510
# Epoch 00083: val_loss improved from 6.52467 to 6.38076, saving model to models/keras_weights.hdf5
# 2653/2653 [==============================] - 0s 48us/sample - loss: 9.7362 - val_loss: 6.3808
# Epoch 84/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 8.6063
# Epoch 00084: val_loss did not improve from 6.38076
# 2653/2653 [==============================] - 0s 38us/sample - loss: 8.5443 - val_loss: 8.0242
# Epoch 85/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 8.4465
# Epoch 00085: val_loss did not improve from 6.38076
# 2653/2653 [==============================] - 0s 37us/sample - loss: 8.0996 - val_loss: 7.4806
# Epoch 86/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 9.4348
# Epoch 00086: val_loss did not improve from 6.38076
# 2653/2653 [==============================] - 0s 38us/sample - loss: 9.8286 - val_loss: 11.3594
# Epoch 87/256
# 2304/2653 [=========================>....] - ETA: 0s - loss: 11.2095
# Epoch 00087: val_loss did not improve from 6.38076
# 2653/2653 [==============================] - 0s 37us/sample - loss: 10.8879 - val_loss: 9.3796
# Epoch 88/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 8.2153
# Epoch 00088: val_loss improved from 6.38076 to 6.32071, saving model to models/keras_weights.hdf5
# 2653/2653 [==============================] - 0s 48us/sample - loss: 8.0609 - val_loss: 6.3207
# Epoch 89/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 11.3160
# Epoch 00089: val_loss did not improve from 6.32071
# 2653/2653 [==============================] - 0s 37us/sample - loss: 12.2746 - val_loss: 13.8596
# Epoch 90/256
# 1920/2653 [====================>.........] - ETA: 0s - loss: 16.6386
# Epoch 00090: val_loss did not improve from 6.32071
# 2653/2653 [==============================] - 0s 40us/sample - loss: 14.3301 - val_loss: 9.8408
# Epoch 91/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 8.4139
# Epoch 00091: val_loss did not improve from 6.32071
# 2653/2653 [==============================] - 0s 40us/sample - loss: 8.2854 - val_loss: 9.2954
# Epoch 92/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 9.0539
# Epoch 00092: val_loss did not improve from 6.32071
# 2653/2653 [==============================] - 0s 37us/sample - loss: 8.6676 - val_loss: 6.4353
# Epoch 93/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 6.9129
# Epoch 00093: val_loss did not improve from 6.32071
# 2653/2653 [==============================] - 0s 37us/sample - loss: 7.3918 - val_loss: 9.6356
# Epoch 94/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 7.9128
# Epoch 00094: val_loss did not improve from 6.32071
# 2653/2653 [==============================] - 0s 37us/sample - loss: 8.7790 - val_loss: 20.5887
# Epoch 95/256
# 2304/2653 [=========================>....] - ETA: 0s - loss: 13.6721
# Epoch 00095: val_loss did not improve from 6.32071
# 2653/2653 [==============================] - 0s 37us/sample - loss: 13.1278 - val_loss: 8.4601
# Epoch 96/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 7.1170
# Epoch 00096: val_loss did not improve from 6.32071
# 2653/2653 [==============================] - 0s 38us/sample - loss: 7.2531 - val_loss: 7.6470
# Epoch 97/256
# 2304/2653 [=========================>....] - ETA: 0s - loss: 8.9823
# Epoch 00097: val_loss did not improve from 6.32071
# 2653/2653 [==============================] - 0s 37us/sample - loss: 9.0311 - val_loss: 8.4510
# Epoch 98/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 9.1761
# Epoch 00098: val_loss did not improve from 6.32071
# 2653/2653 [==============================] - 0s 38us/sample - loss: 8.6275 - val_loss: 6.4403
# Epoch 99/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 7.6040
# Epoch 00099: val_loss did not improve from 6.32071
# 2653/2653 [==============================] - 0s 38us/sample - loss: 7.7251 - val_loss: 7.0865
# Epoch 100/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 9.2075
# Epoch 00100: val_loss did not improve from 6.32071
# 2653/2653 [==============================] - 0s 38us/sample - loss: 9.3956 - val_loss: 7.3734
# Epoch 101/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 9.4120
# Epoch 00101: val_loss did not improve from 6.32071
# 2653/2653 [==============================] - 0s 39us/sample - loss: 8.9428 - val_loss: 10.6990
# Epoch 102/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 8.4425
# Epoch 00102: val_loss did not improve from 6.32071
# 2653/2653 [==============================] - 0s 37us/sample - loss: 8.1875 - val_loss: 7.8493
# Epoch 103/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 8.2546
# Epoch 00103: val_loss did not improve from 6.32071
# 2653/2653 [==============================] - 0s 39us/sample - loss: 8.0516 - val_loss: 6.3755
# Epoch 104/256
# 2304/2653 [=========================>....] - ETA: 0s - loss: 10.7271
# Epoch 00104: val_loss did not improve from 6.32071
# 2653/2653 [==============================] - 0s 37us/sample - loss: 10.8412 - val_loss: 10.0662
# Epoch 105/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 9.2570
# Epoch 00105: val_loss improved from 6.32071 to 6.27469, saving model to models/keras_weights.hdf5
# 2653/2653 [==============================] - 0s 48us/sample - loss: 8.6506 - val_loss: 6.2747
# Epoch 106/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 9.1032
# Epoch 00106: val_loss did not improve from 6.27469
# 2653/2653 [==============================] - 0s 38us/sample - loss: 9.8465 - val_loss: 21.5201
# Epoch 107/256
# 1984/2653 [=====================>........] - ETA: 0s - loss: 10.6598
# Epoch 00107: val_loss did not improve from 6.27469
# 2653/2653 [==============================] - 0s 41us/sample - loss: 10.4059 - val_loss: 7.6891
# Epoch 108/256
# 2304/2653 [=========================>....] - ETA: 0s - loss: 7.7682
# Epoch 00108: val_loss did not improve from 6.27469
# 2653/2653 [==============================] - 0s 37us/sample - loss: 7.4815 - val_loss: 7.2410
# Epoch 109/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 8.0096
# Epoch 00109: val_loss did not improve from 6.27469
# 2653/2653 [==============================] - 0s 39us/sample - loss: 8.0822 - val_loss: 15.1511
# Epoch 110/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 14.5101
# Epoch 00110: val_loss did not improve from 6.27469
# 2653/2653 [==============================] - 0s 38us/sample - loss: 14.9144 - val_loss: 9.4160
# Epoch 111/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 12.2850
# Epoch 00111: val_loss did not improve from 6.27469
# 2653/2653 [==============================] - 0s 37us/sample - loss: 11.3462 - val_loss: 6.5666
# Epoch 112/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 8.0834
# Epoch 00112: val_loss did not improve from 6.27469
# 2653/2653 [==============================] - 0s 38us/sample - loss: 7.7360 - val_loss: 7.7659
# Epoch 113/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 8.4605
# Epoch 00113: val_loss did not improve from 6.27469
# 2653/2653 [==============================] - 0s 38us/sample - loss: 8.2663 - val_loss: 7.9793
# Epoch 114/256
# 2304/2653 [=========================>....] - ETA: 0s - loss: 7.6481
# Epoch 00114: val_loss did not improve from 6.27469
# 2653/2653 [==============================] - 0s 37us/sample - loss: 7.7039 - val_loss: 10.7042
# Epoch 115/256
# 1984/2653 [=====================>........] - ETA: 0s - loss: 6.7049
# Epoch 00115: val_loss improved from 6.27469 to 6.15041, saving model to models/keras_weights.hdf5
# 2653/2653 [==============================] - 0s 50us/sample - loss: 7.7764 - val_loss: 6.1504
# Epoch 116/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 11.0212
# Epoch 00116: val_loss did not improve from 6.15041
# 2653/2653 [==============================] - 0s 38us/sample - loss: 12.1047 - val_loss: 18.0549
# Epoch 117/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 12.4992
# Epoch 00117: val_loss did not improve from 6.15041
# 2653/2653 [==============================] - 0s 38us/sample - loss: 11.8990 - val_loss: 6.1780
# Epoch 118/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 7.4163
# Epoch 00118: val_loss did not improve from 6.15041
# 2653/2653 [==============================] - 0s 37us/sample - loss: 7.1903 - val_loss: 8.0085
# Epoch 119/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 8.8086
# Epoch 00119: val_loss did not improve from 6.15041
# 2653/2653 [==============================] - 0s 39us/sample - loss: 10.1821 - val_loss: 14.8906
# Epoch 120/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 16.2996
# Epoch 00120: val_loss did not improve from 6.15041
# 2653/2653 [==============================] - 0s 37us/sample - loss: 16.1032 - val_loss: 13.9648
# Epoch 121/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 12.6828
# Epoch 00121: val_loss did not improve from 6.15041
# 2653/2653 [==============================] - 0s 38us/sample - loss: 11.5755 - val_loss: 7.1443
# Epoch 122/256
# 2048/2653 [======================>.......] - ETA: 0s - loss: 7.4398
# Epoch 00122: val_loss did not improve from 6.15041
# 2653/2653 [==============================] - 0s 41us/sample - loss: 7.3112 - val_loss: 9.7465
# Epoch 123/256
# 2304/2653 [=========================>....] - ETA: 0s - loss: 7.3739
# Epoch 00123: val_loss did not improve from 6.15041
# 2653/2653 [==============================] - 0s 37us/sample - loss: 7.5553 - val_loss: 6.6270
# Epoch 124/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 9.4065
# Epoch 00124: val_loss did not improve from 6.15041
# 2653/2653 [==============================] - 0s 37us/sample - loss: 10.0262 - val_loss: 7.1436
# Epoch 125/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 17.0329
# Epoch 00125: val_loss did not improve from 6.15041
# 2653/2653 [==============================] - 0s 38us/sample - loss: 16.3034 - val_loss: 8.8649
# Epoch 126/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 8.2309
# Epoch 00126: val_loss did not improve from 6.15041
# 2653/2653 [==============================] - 0s 37us/sample - loss: 8.0400 - val_loss: 7.0130
# Epoch 127/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 11.8843
# Epoch 00127: val_loss did not improve from 6.15041
# 2653/2653 [==============================] - 0s 39us/sample - loss: 10.8792 - val_loss: 6.6818
# Epoch 128/256
# 2304/2653 [=========================>....] - ETA: 0s - loss: 8.5216
# Epoch 00128: val_loss did not improve from 6.15041
# 2653/2653 [==============================] - 0s 36us/sample - loss: 9.1936 - val_loss: 19.1189
# Epoch 129/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 11.0208
# Epoch 00129: val_loss did not improve from 6.15041
# 2653/2653 [==============================] - 0s 38us/sample - loss: 10.9463 - val_loss: 7.8049
# Epoch 130/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 7.4362
# Epoch 00130: val_loss did not improve from 6.15041
# 2653/2653 [==============================] - 0s 37us/sample - loss: 7.1429 - val_loss: 7.1620
# Epoch 131/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 8.7610
# Epoch 00131: val_loss did not improve from 6.15041
# 2653/2653 [==============================] - 0s 38us/sample - loss: 9.1737 - val_loss: 6.2596
# Epoch 132/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 7.2403
# Epoch 00132: val_loss improved from 6.15041 to 6.14160, saving model to models/keras_weights.hdf5
# 2653/2653 [==============================] - 0s 49us/sample - loss: 7.0282 - val_loss: 6.1416
# Epoch 133/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 12.3048
# Epoch 00133: val_loss did not improve from 6.14160
# 2653/2653 [==============================] - 0s 38us/sample - loss: 13.0978 - val_loss: 12.3773
# Epoch 134/256
# 2304/2653 [=========================>....] - ETA: 0s - loss: 10.8326
# Epoch 00134: val_loss did not improve from 6.14160
# 2653/2653 [==============================] - 0s 37us/sample - loss: 10.6694 - val_loss: 8.3814
# Epoch 135/256
# 2048/2653 [======================>.......] - ETA: 0s - loss: 9.7714
# Epoch 00135: val_loss did not improve from 6.14160
# 2653/2653 [==============================] - 0s 38us/sample - loss: 10.7581 - val_loss: 13.7288
# Epoch 136/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 9.9784
# Epoch 00136: val_loss did not improve from 6.14160
# 2653/2653 [==============================] - 0s 39us/sample - loss: 9.9464 - val_loss: 6.3389
# Epoch 137/256
# 2304/2653 [=========================>....] - ETA: 0s - loss: 8.6909
# Epoch 00137: val_loss did not improve from 6.14160
# 2653/2653 [==============================] - 0s 37us/sample - loss: 8.5085 - val_loss: 6.5668
# Epoch 138/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 7.9765
# Epoch 00138: val_loss did not improve from 6.14160
# 2653/2653 [==============================] - 0s 38us/sample - loss: 7.7459 - val_loss: 8.4442
# Epoch 139/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 7.9497
# Epoch 00139: val_loss improved from 6.14160 to 6.14119, saving model to models/keras_weights.hdf5
# 2653/2653 [==============================] - 0s 49us/sample - loss: 8.4471 - val_loss: 6.1412
# Epoch 140/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 8.2641
# Epoch 00140: val_loss did not improve from 6.14119
# 2653/2653 [==============================] - 0s 38us/sample - loss: 7.8653 - val_loss: 8.3726
# Epoch 141/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 8.3884
# Epoch 00141: val_loss did not improve from 6.14119
# 2653/2653 [==============================] - 0s 40us/sample - loss: 8.6531 - val_loss: 10.9962
# Epoch 142/256
# 2048/2653 [======================>.......] - ETA: 0s - loss: 8.7684
# Epoch 00142: val_loss did not improve from 6.14119
# 2653/2653 [==============================] - 0s 39us/sample - loss: 8.6352 - val_loss: 11.2721
# Epoch 143/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 7.8361
# Epoch 00143: val_loss did not improve from 6.14119
# 2653/2653 [==============================] - 0s 38us/sample - loss: 7.4370 - val_loss: 6.2360
# Epoch 144/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 6.8471
# Epoch 00144: val_loss did not improve from 6.14119
# 2653/2653 [==============================] - 0s 40us/sample - loss: 7.3703 - val_loss: 11.3658
# Epoch 145/256
# 2304/2653 [=========================>....] - ETA: 0s - loss: 11.4607
# Epoch 00145: val_loss did not improve from 6.14119
# 2653/2653 [==============================] - 0s 37us/sample - loss: 12.0200 - val_loss: 18.8348
# Epoch 146/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 14.0479
# Epoch 00146: val_loss improved from 6.14119 to 6.09904, saving model to models/keras_weights.hdf5
# 2653/2653 [==============================] - 0s 49us/sample - loss: 12.6954 - val_loss: 6.0990
# Epoch 147/256
# 1920/2653 [====================>.........] - ETA: 0s - loss: 8.4967
# Epoch 00147: val_loss did not improve from 6.09904
# 2653/2653 [==============================] - 0s 43us/sample - loss: 8.4812 - val_loss: 11.4560
# Epoch 148/256
# 2048/2653 [======================>.......] - ETA: 0s - loss: 9.4673
# Epoch 00148: val_loss did not improve from 6.09904
# 2653/2653 [==============================] - 0s 39us/sample - loss: 9.0644 - val_loss: 9.9132
# Epoch 149/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 8.6076
# Epoch 00149: val_loss did not improve from 6.09904
# 2653/2653 [==============================] - 0s 38us/sample - loss: 9.9733 - val_loss: 17.4083
# Epoch 150/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 16.1348
# Epoch 00150: val_loss did not improve from 6.09904
# 2653/2653 [==============================] - 0s 38us/sample - loss: 15.4116 - val_loss: 12.6811
# Epoch 151/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 8.7166
# Epoch 00151: val_loss did not improve from 6.09904
# 2653/2653 [==============================] - 0s 38us/sample - loss: 9.0109 - val_loss: 6.5231
# Epoch 152/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 8.5812
# Epoch 00152: val_loss did not improve from 6.09904
# 2653/2653 [==============================] - 0s 38us/sample - loss: 8.1707 - val_loss: 6.4217
# Epoch 153/256
# 1984/2653 [=====================>........] - ETA: 0s - loss: 8.3518
# Epoch 00153: val_loss did not improve from 6.09904
# 2653/2653 [==============================] - 0s 39us/sample - loss: 7.7168 - val_loss: 6.4350
# Epoch 154/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 8.8256
# Epoch 00154: val_loss did not improve from 6.09904
# 2653/2653 [==============================] - 0s 37us/sample - loss: 8.8461 - val_loss: 6.7122
# Epoch 155/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 7.3995
# Epoch 00155: val_loss did not improve from 6.09904
# 2653/2653 [==============================] - 0s 38us/sample - loss: 6.9853 - val_loss: 6.1418
# Epoch 156/256
# 1984/2653 [=====================>........] - ETA: 0s - loss: 7.4725
# Epoch 00156: val_loss did not improve from 6.09904
# 2653/2653 [==============================] - 0s 39us/sample - loss: 7.2886 - val_loss: 8.5271
# Epoch 157/256
# 2304/2653 [=========================>....] - ETA: 0s - loss: 9.6817
# Epoch 00157: val_loss did not improve from 6.09904
# 2653/2653 [==============================] - 0s 37us/sample - loss: 9.6286 - val_loss: 6.6595
# Epoch 158/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 7.9703
# Epoch 00158: val_loss did not improve from 6.09904
# 2653/2653 [==============================] - 0s 39us/sample - loss: 8.3785 - val_loss: 7.9339
# Epoch 159/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 9.6214
# Epoch 00159: val_loss did not improve from 6.09904
# 2653/2653 [==============================] - 0s 38us/sample - loss: 10.4903 - val_loss: 23.8619
# Epoch 160/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 14.2982
# Epoch 00160: val_loss did not improve from 6.09904
# 2653/2653 [==============================] - 0s 37us/sample - loss: 13.7498 - val_loss: 9.8311
# Epoch 161/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 9.1453
# Epoch 00161: val_loss did not improve from 6.09904
# 2653/2653 [==============================] - 0s 37us/sample - loss: 8.6823 - val_loss: 7.3530
# Epoch 162/256
# 1920/2653 [====================>.........] - ETA: 0s - loss: 8.1588
# Epoch 00162: val_loss did not improve from 6.09904
# 2653/2653 [==============================] - 0s 40us/sample - loss: 8.0346 - val_loss: 12.7745
# Epoch 163/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 9.2633
# Epoch 00163: val_loss did not improve from 6.09904
# 2653/2653 [==============================] - 0s 38us/sample - loss: 9.8354 - val_loss: 16.8170
# Epoch 164/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 16.0857
# Epoch 00164: val_loss improved from 6.09904 to 6.03085, saving model to models/keras_weights.hdf5
# 2653/2653 [==============================] - 0s 48us/sample - loss: 15.0676 - val_loss: 6.0308
# Epoch 165/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 8.8753
# Epoch 00165: val_loss did not improve from 6.03085
# 2653/2653 [==============================] - 0s 38us/sample - loss: 8.4248 - val_loss: 6.5588
# Epoch 166/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 7.9518
# Epoch 00166: val_loss did not improve from 6.03085
# 2653/2653 [==============================] - 0s 39us/sample - loss: 8.4602 - val_loss: 7.6390
# Epoch 167/256
# 1984/2653 [=====================>........] - ETA: 0s - loss: 8.9700
# Epoch 00167: val_loss did not improve from 6.03085
# 2653/2653 [==============================] - 0s 41us/sample - loss: 8.8309 - val_loss: 6.1370
# Epoch 168/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 10.1752
# Epoch 00168: val_loss did not improve from 6.03085
# 2653/2653 [==============================] - 0s 38us/sample - loss: 9.6495 - val_loss: 6.2318
# Epoch 169/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 8.0838
# Epoch 00169: val_loss did not improve from 6.03085
# 2653/2653 [==============================] - 0s 37us/sample - loss: 8.5375 - val_loss: 8.7810
# Epoch 170/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 7.6892
# Epoch 00170: val_loss did not improve from 6.03085
# 2653/2653 [==============================] - 0s 38us/sample - loss: 8.0736 - val_loss: 8.2700
# Epoch 171/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 8.7113
# Epoch 00171: val_loss did not improve from 6.03085
# 2653/2653 [==============================] - 0s 38us/sample - loss: 8.6825 - val_loss: 7.7406
# Epoch 172/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 9.1146
# Epoch 00172: val_loss did not improve from 6.03085
# 2653/2653 [==============================] - 0s 39us/sample - loss: 8.4978 - val_loss: 6.3838
# Epoch 173/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 8.5126
# Epoch 00173: val_loss did not improve from 6.03085
# 2653/2653 [==============================] - 0s 38us/sample - loss: 8.2391 - val_loss: 7.8853
# Epoch 174/256
# 2304/2653 [=========================>....] - ETA: 0s - loss: 9.3291
# Epoch 00174: val_loss did not improve from 6.03085
# 2653/2653 [==============================] - 0s 37us/sample - loss: 9.7444 - val_loss: 6.8144
# Epoch 175/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 10.3194
# Epoch 00175: val_loss did not improve from 6.03085
# 2653/2653 [==============================] - 0s 39us/sample - loss: 9.6710 - val_loss: 9.8157
# Epoch 176/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 9.6539
# Epoch 00176: val_loss did not improve from 6.03085
# 2653/2653 [==============================] - 0s 37us/sample - loss: 9.5156 - val_loss: 6.1309
# Epoch 177/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 6.5176
# Epoch 00177: val_loss did not improve from 6.03085
# 2653/2653 [==============================] - 0s 37us/sample - loss: 6.9961 - val_loss: 7.4406
# Epoch 178/256
# 1344/2653 [==============>...............] - ETA: 0s - loss: 7.3463
# Epoch 00178: val_loss did not improve from 6.03085
# 2653/2653 [==============================] - 0s 49us/sample - loss: 9.7704 - val_loss: 14.6256
# Epoch 179/256
# 2304/2653 [=========================>....] - ETA: 0s - loss: 8.8606
# Epoch 00179: val_loss did not improve from 6.03085
# 2653/2653 [==============================] - 0s 37us/sample - loss: 8.8725 - val_loss: 10.4723
# Epoch 180/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 8.2248
# Epoch 00180: val_loss did not improve from 6.03085
# 2653/2653 [==============================] - 0s 37us/sample - loss: 8.1102 - val_loss: 6.7425
# Epoch 181/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 8.0822
# Epoch 00181: val_loss did not improve from 6.03085
# 2653/2653 [==============================] - 0s 38us/sample - loss: 8.1241 - val_loss: 7.3056
# Epoch 182/256
# 1984/2653 [=====================>........] - ETA: 0s - loss: 8.5924
# Epoch 00182: val_loss did not improve from 6.03085
# 2653/2653 [==============================] - 0s 39us/sample - loss: 9.0837 - val_loss: 9.9592
# Epoch 183/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 9.7351
# Epoch 00183: val_loss did not improve from 6.03085
# 2653/2653 [==============================] - 0s 37us/sample - loss: 9.8185 - val_loss: 7.5230
# Epoch 184/256
# 2048/2653 [======================>.......] - ETA: 0s - loss: 11.1344
# Epoch 00184: val_loss did not improve from 6.03085
# 2653/2653 [==============================] - 0s 38us/sample - loss: 10.1202 - val_loss: 6.1379
# Epoch 185/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 6.9707
# Epoch 00185: val_loss did not improve from 6.03085
# 2653/2653 [==============================] - 0s 37us/sample - loss: 8.0443 - val_loss: 10.0036
# Epoch 186/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 6.9734
# Epoch 00186: val_loss did not improve from 6.03085
# 2653/2653 [==============================] - 0s 38us/sample - loss: 7.1388 - val_loss: 7.0143
# Epoch 187/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 12.7568
# Epoch 00187: val_loss did not improve from 6.03085
# 2653/2653 [==============================] - 0s 39us/sample - loss: 13.5176 - val_loss: 12.2973
# Epoch 188/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 15.4266
# Epoch 00188: val_loss did not improve from 6.03085
# 2653/2653 [==============================] - 0s 38us/sample - loss: 14.2845 - val_loss: 8.7375
# Epoch 189/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 8.8835
# Epoch 00189: val_loss did not improve from 6.03085
# 2653/2653 [==============================] - 0s 38us/sample - loss: 8.3254 - val_loss: 7.8412
# Epoch 190/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 7.7571
# Epoch 00190: val_loss did not improve from 6.03085
# 2653/2653 [==============================] - 0s 38us/sample - loss: 7.6040 - val_loss: 6.0635
# Epoch 191/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 8.0251
# Epoch 00191: val_loss did not improve from 6.03085
# 2653/2653 [==============================] - 0s 37us/sample - loss: 7.7864 - val_loss: 6.7248
# Epoch 192/256
# 1856/2653 [===================>..........] - ETA: 0s - loss: 8.5582
# Epoch 00192: val_loss did not improve from 6.03085
# 2653/2653 [==============================] - 0s 42us/sample - loss: 9.2672 - val_loss: 8.1845
# Epoch 193/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 9.0314
# Epoch 00193: val_loss did not improve from 6.03085
# 2653/2653 [==============================] - 0s 38us/sample - loss: 8.4644 - val_loss: 6.4527
# Epoch 194/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 7.1425
# Epoch 00194: val_loss did not improve from 6.03085
# 2653/2653 [==============================] - 0s 38us/sample - loss: 7.6010 - val_loss: 8.8729
# Epoch 195/256
# 2304/2653 [=========================>....] - ETA: 0s - loss: 7.9084
# Epoch 00195: val_loss improved from 6.03085 to 5.97361, saving model to models/keras_weights.hdf5
# 2653/2653 [==============================] - 0s 48us/sample - loss: 7.6807 - val_loss: 5.9736
# Epoch 196/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 9.6604
# Epoch 00196: val_loss did not improve from 5.97361
# 2653/2653 [==============================] - 0s 39us/sample - loss: 9.8650 - val_loss: 10.1790
# Epoch 197/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 9.7422
# Epoch 00197: val_loss did not improve from 5.97361
# 2653/2653 [==============================] - 0s 38us/sample - loss: 11.0339 - val_loss: 15.6403
# Epoch 198/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 12.5001
# Epoch 00198: val_loss did not improve from 5.97361
# 2653/2653 [==============================] - 0s 38us/sample - loss: 11.9158 - val_loss: 9.2045
# Epoch 199/256
# 2048/2653 [======================>.......] - ETA: 0s - loss: 6.9013
# Epoch 00199: val_loss did not improve from 5.97361
# 2653/2653 [==============================] - 0s 38us/sample - loss: 7.7553 - val_loss: 10.5150
# Epoch 200/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 7.8594
# Epoch 00200: val_loss did not improve from 5.97361
# 2653/2653 [==============================] - 0s 38us/sample - loss: 8.0576 - val_loss: 6.6478
# Epoch 201/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 9.3896
# Epoch 00201: val_loss did not improve from 5.97361
# 2653/2653 [==============================] - 0s 38us/sample - loss: 10.4172 - val_loss: 14.6317
# Epoch 202/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 11.8542
# Epoch 00202: val_loss did not improve from 5.97361
# 2653/2653 [==============================] - 0s 38us/sample - loss: 11.7488 - val_loss: 10.7455
# Epoch 203/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 9.3309
# Epoch 00203: val_loss did not improve from 5.97361
# 2653/2653 [==============================] - 0s 37us/sample - loss: 10.1465 - val_loss: 30.5864
# Epoch 204/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 15.0437
# Epoch 00204: val_loss did not improve from 5.97361
# 2653/2653 [==============================] - 0s 38us/sample - loss: 15.5946 - val_loss: 20.4952
# Epoch 205/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 16.4881
# Epoch 00205: val_loss did not improve from 5.97361
# 2653/2653 [==============================] - 0s 38us/sample - loss: 16.7167 - val_loss: 7.6409
# Epoch 206/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 7.3961
# Epoch 00206: val_loss did not improve from 5.97361
# 2653/2653 [==============================] - 0s 37us/sample - loss: 7.4845 - val_loss: 6.2332
# Epoch 207/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 9.7883
# Epoch 00207: val_loss did not improve from 5.97361
# 2653/2653 [==============================] - 0s 38us/sample - loss: 10.0624 - val_loss: 16.1486
# Epoch 208/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 13.1584
# Epoch 00208: val_loss did not improve from 5.97361
# 2653/2653 [==============================] - 0s 38us/sample - loss: 12.3415 - val_loss: 6.2642
# Epoch 209/256
# 2048/2653 [======================>.......] - ETA: 0s - loss: 7.7389
# Epoch 00209: val_loss did not improve from 5.97361
# 2653/2653 [==============================] - 0s 38us/sample - loss: 7.7003 - val_loss: 8.2019
# Epoch 210/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 10.9100
# Epoch 00210: val_loss did not improve from 5.97361
# 2653/2653 [==============================] - 0s 38us/sample - loss: 10.8467 - val_loss: 6.6971
# Epoch 211/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 13.7471
# Epoch 00211: val_loss did not improve from 5.97361
# 2653/2653 [==============================] - 0s 38us/sample - loss: 13.8968 - val_loss: 11.9792
# Epoch 212/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 13.6296
# Epoch 00212: val_loss did not improve from 5.97361
# 2653/2653 [==============================] - 0s 37us/sample - loss: 12.6859 - val_loss: 6.8692
# Epoch 213/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 7.9498
# Epoch 00213: val_loss did not improve from 5.97361
# 2653/2653 [==============================] - 0s 37us/sample - loss: 7.8364 - val_loss: 8.0558
# Epoch 214/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 7.2268
# Epoch 00214: val_loss did not improve from 5.97361
# 2653/2653 [==============================] - 0s 38us/sample - loss: 7.4941 - val_loss: 9.5877
# Epoch 215/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 8.8597
# Epoch 00215: val_loss did not improve from 5.97361
# 2653/2653 [==============================] - 0s 38us/sample - loss: 8.3027 - val_loss: 6.0387
# Epoch 216/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 8.3811
# Epoch 00216: val_loss did not improve from 5.97361
# 2653/2653 [==============================] - 0s 37us/sample - loss: 8.1531 - val_loss: 6.0130
# Epoch 217/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 9.8602
# Epoch 00217: val_loss did not improve from 5.97361
# 2653/2653 [==============================] - 0s 39us/sample - loss: 8.9818 - val_loss: 6.0302
# Epoch 218/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 7.1365
# Epoch 00218: val_loss did not improve from 5.97361
# 2653/2653 [==============================] - 0s 38us/sample - loss: 7.6795 - val_loss: 9.5745
# Epoch 219/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 8.5922
# Epoch 00219: val_loss did not improve from 5.97361
# 2653/2653 [==============================] - 0s 37us/sample - loss: 8.6967 - val_loss: 6.7567
# Epoch 220/256
# 2240/2653 [========================>.....] - ETA: 0s - loss: 7.0806
# Epoch 00220: val_loss did not improve from 5.97361
# 2653/2653 [==============================] - 0s 37us/sample - loss: 7.3534 - val_loss: 6.3290
# Epoch 221/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 9.4752
# Epoch 00221: val_loss did not improve from 5.97361
# 2653/2653 [==============================] - 0s 38us/sample - loss: 8.7840 - val_loss: 6.5611
# Epoch 222/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 7.7175
# Epoch 00222: val_loss did not improve from 5.97361
# 2653/2653 [==============================] - 0s 38us/sample - loss: 7.9743 - val_loss: 9.2560
# Epoch 223/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 7.5203
# Epoch 00223: val_loss did not improve from 5.97361
# 2653/2653 [==============================] - 0s 38us/sample - loss: 7.1406 - val_loss: 6.3310
# Epoch 224/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 10.1434
# Epoch 00224: val_loss did not improve from 5.97361
# 2653/2653 [==============================] - 0s 38us/sample - loss: 9.4558 - val_loss: 6.8801
# Epoch 225/256
# 2176/2653 [=======================>......] - ETA: 0s - loss: 8.5478
# Epoch 00225: val_loss did not improve from 5.97361
# 2653/2653 [==============================] - 0s 38us/sample - loss: 8.3845 - val_loss: 6.8217
# Epoch 226/256
# 2112/2653 [======================>.......] - ETA: 0s - loss: 8.7899
# Epoch 00226: val_loss did not improve from 5.97361
# 2653/2653 [==============================] - 0s 38us/sample - loss: 9.3709 - val_loss: 15.5313
# Epoch 227/256
# 2304/2653 [=========================>....] - ETA: 0s - loss: 11.4573
# Epoch 00227: val_loss did not improve from 5.97361
# 2653/2653 [==============================] - 0s 37us/sample - loss: 11.9903 - val_loss: 12.0961

# %% [markdown]
# ### Load model

# %%
def load_trained_model():
    model = build_model()
    model.load_weights('models/keras_weights.hdf5')
    
    return model

model = load_trained_model()

# %%
model.save('model')

# %%
import keras

# %%
keras.__version__
# Out:
# '2.3.1'

# %% [markdown]
# #### Baseline functions
# * Roll - always predict previous price
# * Zero - always predict zero

# %%
def rmse(y_true, y_pred):
    return sqrt(mean_squared_error(y_true, y_pred))

def predict_roll(data):
    return sqrt(mean_squared_error(np.roll(data, 1)[1:], data[1:]))

def predict_zero(data):
    return sqrt(mean_squared_error(np.zeros_like(data), data))

# %%
# Predict using the test data
y_hat = model.predict(X_test)
y_hat_train = model.predict(X_train)

# %%
# Test baseline
print('Test baseline roll: ${:.2f}'.format(predict_roll(y_test)))
print('Test baseline zero: ${:.2f}'.format(predict_zero(y_test)))
print('Test RMSE: ${:.2f}'.format(rmse(y_hat, y_test)))
# Out:
# Test baseline roll: $6.64
# Test baseline zero: $8865.66
# Test RMSE: $9.07

# %%
# Train baseline
print('Train baseline roll: ${:.2f}'.format(predict_roll(y_train)))
print('Train baseline zero: ${:.2f}'.format(predict_zero(y_train)))
print('Train RMSE: ${:.2f}'.format(rmse(y_hat_train, y_train)))
# Out:
# Train baseline roll: $4.85
# Train baseline zero: $9150.96
# Train RMSE: $7.17

# %%
sns.set(style='darkgrid')
plt.plot(np.roll(y_test, 1)[-50:], label='roll price', color='lightgray', marker='o', markersize=3)
plt.plot(y_test[-50:], label='real price', marker='o', markersize=3)
plt.plot(y_hat[-50:], linestyle='dashed', label='predicted price', marker='o', markersize=3)
plt.title('Test data prediction')
plt.legend();

# %%
sns.set(style='darkgrid')
plt.plot(y_train[:100], label='real price')
plt.plot(y_hat_train[:100], linestyle='dashed', label='predicted price')
plt.title('Train data prediction')
plt.legend();

# %% [markdown]
# #### Hyperopt

# %%
def root_mean_squared_error(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

def build_model(dense_layers=2, dense_hidden_size=8, dropout_rate=0, l1_reg=0, l2_reg=0, 
                optimizer_function='adam', learning_rate=0.001, **arg):
    model = Sequential()
    model.add(Dense(dense_hidden_size, activation='relu', input_shape=(X_train.shape[1],),
                    kernel_regularizer=regularizers.l1_l2(l1=l1_reg, l2=l2_reg)
                   ))
    model.add(Dropout(dropout_rate))
    
    for layer in range(dense_layers-1):
        model.add(Dense(dense_hidden_size, activation='relu', 
                        kernel_regularizer=regularizers.l1_l2(l1=l1_reg, l2=l2_reg)
                       ))
        model.add(Dropout(dropout_rate))
        
    model.add(Dense(1))
    
    model.compile(optimizer=optimizer_function, loss=root_mean_squared_error)
    
    return model

# %%
space = {'dense_layers': hp.choice('dense_layers', [1, 2]),
         
         'dense_hidden_size': hp.choice('dense_hidden_size', [8, 16, 32]),
         
         'regularization': hp.choice('regularization', 
                                     [{'reg_type': 'dropout',
                                       'dropout_rate': hp.choice('dropout_rate', [0.20, 0.35, 0.50])},
                                       {'reg_type': 'l1', 
                                        'l1_reg': hp.loguniform('l1_reg', -9, -2)}, 
                                       {'reg_type': 'l2', 
                                        'l2_reg': hp.loguniform('l2_reg', -9, -2)}]),
         
         'optimizer_function': hp.choice('optimizer_function', ['adam', 'RMSprop'])
        }

# %%
def hyperopt_wrapper(params):
    print('Params testing: ', params)
    
    model = build_model(**params)
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=32)
    
    checkpointer = ModelCheckpoint(filepath='models/keras_weights.hdf5',
                                   verbose=0,
                                   save_best_only=True)
    
    result = model.fit(X_train, 
                        y_train, 
                        verbose=0,
                        validation_split=0.33,
                        epochs=256, 
                        batch_size=64,
                        callbacks=[checkpointer, early_stopping])
    
    loss = np.amin(result.history['val_loss'])
    
    print('Best validation loss of epoch:', loss)
    return {'loss': loss, 'status': STATUS_OK, 'trained_model': model}

# %%
trials = Trials()
best = fmin(hyperopt_wrapper, 
            space, 
            algo=tpe.suggest, 
            max_evals=15, 
            trials=trials)
# Out:
# Params testing:
# {'dense_hidden_size': 8, 'dense_layers': 1, 'optimizer_function': 'adam', 'regularization': {'l1_reg': 0.0031361025517894934, 'reg_type': 'l1'}}
# Best validation loss of epoch:
# 7.038304242883618
# Params testing:
# {'dense_hidden_size': 8, 'dense_layers': 1, 'optimizer_function': 'adam', 'regularization': {'l1_reg': 0.008096140648798635, 'reg_type': 'l1'}}
# Best validation loss of epoch:
# 7.884603942206146
# Params testing:
# {'dense_hidden_size': 32, 'dense_layers': 1, 'optimizer_function': 'adam', 'regularization': {'l2_reg': 0.04194263892736314, 'reg_type': 'l2'}}
# Best validation loss of epoch:
# 6.850904292652002
# Params testing:
# {'dense_hidden_size': 32, 'dense_layers': 2, 'optimizer_function': 'RMSprop', 'regularization': {'dropout_rate': 0.5, 'reg_type': 'dropout'}}
# Best validation loss of epoch:
# 36.7611503251102
# Params testing:
# {'dense_hidden_size': 16, 'dense_layers': 1, 'optimizer_function': 'adam', 'regularization': {'l1_reg': 0.00013895992571692976, 'reg_type': 'l1'}}
# Best validation loss of epoch:
# 7.573980064567076
# Params testing:
# {'dense_hidden_size': 16, 'dense_layers': 2, 'optimizer_function': 'RMSprop', 'regularization': {'dropout_rate': 0.2, 'reg_type': 'dropout'}}
# Best validation loss of epoch:
# 37.627483426248624
# Params testing:
# {'dense_hidden_size': 8, 'dense_layers': 1, 'optimizer_function': 'adam', 'regularization': {'dropout_rate': 0.35, 'reg_type': 'dropout'}}
# Best validation loss of epoch:
# 5.603909873816581
# Params testing:
# {'dense_hidden_size': 32, 'dense_layers': 2, 'optimizer_function': 'RMSprop', 'regularization': {'l2_reg': 0.00171277424322985, 'reg_type': 'l2'}}
# Best validation loss of epoch:
# 30.216974865041376
# Params testing:
# {'dense_hidden_size': 32, 'dense_layers': 1, 'optimizer_function': 'adam', 'regularization': {'dropout_rate': 0.2, 'reg_type': 'dropout'}}
# Best validation loss of epoch:
# 5.974801815977884
# Params testing:
# {'dense_hidden_size': 16, 'dense_layers': 2, 'optimizer_function': 'adam', 'regularization': {'l1_reg': 0.0006968527749852183, 'reg_type': 'l1'}}
# Best validation loss of epoch:
# 5.596695340007817
# Params testing:
# {'dense_hidden_size': 8, 'dense_layers': 1, 'optimizer_function': 'RMSprop', 'regularization': {'l2_reg': 0.0036234393522502372, 'reg_type': 'l2'}}
# Best validation loss of epoch:
# 8833.114574374044
# Params testing:
# {'dense_hidden_size': 32, 'dense_layers': 1, 'optimizer_function': 'RMSprop', 'regularization': {'dropout_rate': 0.35, 'reg_type': 'dropout'}}
# Best validation loss of epoch:
# 73.49406806409176
# Params testing:
# {'dense_hidden_size': 16, 'dense_layers': 1, 'optimizer_function': 'RMSprop', 'regularization': {'l2_reg': 0.0295291422010777, 'reg_type': 'l2'}}
# Best validation loss of epoch:
# 39.21550068286581
# Params testing:
# {'dense_hidden_size': 8, 'dense_layers': 1, 'optimizer_function': 'RMSprop', 'regularization': {'dropout_rate': 0.5, 'reg_type': 'dropout'}}
# Best validation loss of epoch:
# 8833.115338900037
# Params testing:
# {'dense_hidden_size': 32, 'dense_layers': 1, 'optimizer_function': 'adam', 'regularization': {'dropout_rate': 0.35, 'reg_type': 'dropout'}}
# Best validation loss of epoch:
# 6.711664150249703
# 100%|██████████| 15/15 [04:47<00:00, 17.30s/it, best loss: 5.596695340007817]

# %%
best_model = trials.results[np.argmin([r['loss'] for r in trials.results])]['trained_model']

# %%
config = best_model.get_config()

# %%
model = Sequential.from_config(config)
model.compile(optimizer='adam', loss=root_mean_squared_error)

# %%
model.summary()
# Out:
# Model: "sequential_45"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_128 (Dense)            (None, 16)                160
# _________________________________________________________________
# dropout_79 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_129 (Dense)            (None, 16)                272
# _________________________________________________________________
# dropout_80 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_130 (Dense)            (None, 1)                 17
# =================================================================
# Total params: 449
# Trainable params: 449
# Non-trainable params: 0
# _________________________________________________________________

# %%
result = model.fit(X_train, 
                   y_train, 
                   verbose=0,
                   epochs=256, 
                   batch_size=64,
                   callbacks=[checkpointer, early_stopping])

# %%
def rmse(y_true, y_pred):
    return sqrt(mean_squared_error(y_true, y_pred))

def predict_roll(data):
    return sqrt(mean_squared_error(np.roll(data, 1)[1:], data[1:]))

def predict_zero(data):
    return sqrt(mean_squared_error(np.zeros_like(data), data))

# %%
# Predict using the test data
y_hat = model.predict(X_test)
y_hat_train = model.predict(X_train)

# %%
# Test baseline
print('Test baseline roll: ${:.2f}'.format(predict_roll(y_test)))
print('Test baseline zero: ${:.2f}'.format(predict_zero(y_test)))
print('Test RMSE: ${:.2f}'.format(rmse(y_hat, y_test)))
# Out:
# Test baseline roll: $6.64
# Test baseline zero: $8865.66
# Test RMSE: $18.11

# %%
# Train baseline
print('Train baseline roll: ${:.2f}'.format(predict_roll(y_train)))
print('Train baseline zero: ${:.2f}'.format(predict_zero(y_train)))
print('Train RMSE: ${:.2f}'.format(rmse(y_hat_train, y_train)))
# Out:
# Train baseline roll: $4.85
# Train baseline zero: $9150.96
# Train RMSE: $17.33

# %%
sns.set(style='darkgrid')
plt.plot(np.roll(y_test, 1)[-50:], label='roll price', color='lightgray', marker='o', markersize=3)
plt.plot(y_test[-50:], label='real price', marker='o', markersize=3)
plt.plot(y_hat[-50:], linestyle='dashed', label='predicted price', marker='o', markersize=3)
plt.title('Test data prediction')
plt.legend();

# %%
sns.set(style='darkgrid')
plt.plot(y_train[:100], label='real price')
plt.plot(y_hat_train[:100], linestyle='dashed', label='predicted price')
plt.title('Train data prediction')
plt.legend();

# %% [markdown]
# ### XGBoost

# %%
from hyperopt import hp, fmin, tpe, STATUS_OK, STATUS_FAIL, Trials, space_eval, rand

# %%
# XGB parameters
xgb_reg_params = {
    'learning_rate':    hp.choice('learning_rate',    np.arange(0.05, 0.31, 0.05)),
    'max_depth':        hp.choice('max_depth',        np.arange(5, 16, 1, dtype=int)),
    'min_child_weight': hp.choice('min_child_weight', np.arange(1, 8, 1, dtype=int)),
    'colsample_bytree': hp.choice('colsample_bytree', np.arange(0.3, 0.8, 0.1)),
    'subsample':        hp.uniform('subsample', 0.8, 1),
    'objective':        'reg:squarederror',
    'n_estimators':     10000
}

xgb_fit_params = {
    'eval_metric': 'rmse',
    'early_stopping_rounds': 10,
    'verbose': False
}

xgb_data_params = {
    'n_steps': hp.choice('n_steps', np.arange(1, 24, 1, dtype=int)),
}

xgb_parameters = dict()
xgb_parameters['reg_params']  = xgb_reg_params
xgb_parameters['fit_params']  = xgb_fit_params
xgb_parameters['data_params'] = xgb_data_params

# %%
class Hyperopt():
    
    def process(self, fn_name, space, trials, algo, max_evals):
        fn = getattr(self, fn_name)
        try:
            result = fmin(fn=fn, space=space, algo=algo, max_evals=max_evals, trials=trials)
        except Exception as e:
            print({'status': STATUS_FAIL, 'exception': str(e)})
        else:
            return result, trials

    def xgb_regression(self, parameters):
        model = XGBRegressor(**parameters['reg_params'])
        return self.train(model, parameters)

    def train(self, model, parameters):
        X_train, X_test, y_train, y_test = generate_train_test(**parameters['data_params'])
        
        model.fit(X_train, y_train,
                eval_set=[(X_train, y_train), (X_test, y_test)],
                **parameters['fit_params'])
        
        y_hat = model.predict(X_test)
        loss = np.sqrt(mean_squared_error(y_test, y_hat))
        
        return {'loss': loss, 'status': STATUS_OK, 'model': model}

# %%
optimizer = Hyperopt()

best, trails = optimizer.process(
    fn_name='xgb_regression', 
    space=xgb_parameters, 
    trials=Trials(), 
    algo=rand.suggest,
    max_evals=20)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 20/20 [01:29<00:00,  2.88s/it, best loss: 38.095362672543025]

# %%
def get_best_model(trails):
    best_idx = np.argmin([trail['result']['loss'] for trail in trails])
    return list(trails)[best_idx]['result']['model']

def get_best_data_params(parameters, best_params):
    return space_eval(parameters, best_params)['data_params']

# %%
data_params = get_best_data_params(xgb_parameters, best)

X_train, X_test, y_train, y_test = generate_train_test(**data_params)

# %%
xgboost = get_best_model(trails)

# %%
# Predict using the test data
y_hat = xgboost.predict(X_test)
y_hat_train = xgboost.predict(X_train)

# %%
# Test baseline
print('Test baseline roll: ${:.2f}'.format(predict_roll(y_test)))
print('Test baseline zero: ${:.2f}'.format(predict_zero(y_test)))
print('Test RMSE: ${:.2f}'.format(rmse(y_hat, y_test)))
# Out:
# Test baseline roll: $34.88
# Test baseline zero: $5327.72
# Test RMSE: $38.10

# %%
# Train baseline
print('Train baseline roll: ${:.2f}'.format(predict_roll(y_train)))
print('Train baseline zero: ${:.2f}'.format(predict_zero(y_train)))
print('Train RMSE: ${:.2f}'.format(rmse(y_hat_train, y_train)))
# Out:
# Train baseline roll: $116.47
# Train baseline zero: $8599.96
# Train RMSE: $76.55

# %%
plt.plot(np.roll(y_test, 1)[1:50], label='roll price', color='lightgray', marker='o', markersize=3)
plt.plot(y_test[1:50], label='real price', marker='o', markersize=3)
plt.plot(y_hat[1:50], linestyle='dashed', label='predicted price', marker='o', markersize=3)
plt.title('Test data prediction')
plt.legend();

# %%
plt.plot(y_train[:100], label='real price')
plt.plot(y_hat_train[:100], linestyle='dashed', label='predicted price')
plt.title('Train data prediction')
plt.legend();
